# %%
import pandas as pd

# %%
# Define the file path
file_path = 'eu_bdt-ud-dev.conllu'

# Define column names
column_names = ['id', 'form', 'lemma', 'upos', '_1', '_2', '_3', '_4', '_5', '_6', '_7', '_8', '_9']

# Read the file, skipping comments and empty lines
with open(file_path, 'r', encoding='utf-8') as f:
    data = [line.strip().split('\t') for line in f if line.strip() and not line.startswith('#')]

# Pad each line with empty strings to ensure it has 13 columns
data = [row + [''] * (len(column_names) - len(row)) if len(row) < len(column_names) else row for row in data]

# Create the DataFrame
df = pd.DataFrame(data, columns=column_names)

# Convert 'id' and '_3' columns to numeric, coercing errors to NaN
df['id'] = pd.to_numeric(df['id'], errors='coerce')
df['_3'] = pd.to_numeric(df['_3'], errors='coerce')

# Print the DataFrame
print(df)

# Get a summary of the DataFrame
print("\nSummary:")
df.info()
# Out:
#        id      form   lemma   upos _1  \
# 0       1  Atenasen  Atenas  PROPN  _
# 1       2     ordea   ordea  CCONJ  _
# 2       3         ,       ,  PUNCT  _
# 3       4     beste   beste    DET  _
# 4       5      bost    bost    NUM  _
# ...    ..       ...     ...    ... ..
# 24090  21      izan    izan    AUX  _
# 24091  22        da    izan    AUX  _
# 24092  23       lur     lur   NOUN  _
# 24093  24      hura    hura    DET  _
# 24094  25         .       .  PUNCT  _
#
#                                                       _2  _3      _4 _5  \
# 0                      Case=Ine|Definite=Def|Number=Sing   8     obl  _
# 1                                                      _   8  advmod  _
# 2                                                      _   2   punct  _
# 3                                                      _   6     det  _
# 4                                           NumType=Card   6  nummod  _
# ...                                                  ...  ..     ... ..
# 24090                          Aspect=Perf|VerbForm=Part  20     cop  _
# 24091  Mood=Ind|Number[abs]=Sing|Person[abs]=3|VerbFo...  20     aux  _
# 24092                                                  _  20   nsubj  _
# 24093                  Case=Abs|Definite=Def|Number=Sing  23     det  _
# 24094                                                  _   9   punct  _
#
#                   _6 _7 _8 _9
# 0                  _
# 1      SpaceAfter=No
# 2                  _
# 3                  _
# 4                  _
# ...              ... .. .. ..
# 24090              _
# 24091              _
# 24092              _
# 24093  SpaceAfter=No
# 24094              _
#
# [24095 rows x 13 columns]
#
# Summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24095 entries, 0 to 24094
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      24095 non-null  int64
#  1   form    24095 non-null  object
#  2   lemma   24095 non-null  object
#  3   upos    24095 non-null  object
#  4   _1      24095 non-null  object
#  5   _2      24095 non-null  object
#  6   _3      24095 non-null  int64
#  7   _4      24095 non-null  object
#  8   _5      24095 non-null  object
#  9   _6      24095 non-null  object
#  10  _7      24095 non-null  object
#  11  _8      24095 non-null  object
#  12  _9      24095 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 2.4+ MB

# %%
import matplotlib.pyplot as plt #Import Matplotlib for plotting


# Define the file path
file_path = 'eu_bdt-ud-dev.conllu'

# Define column names
column_names = ['id', 'form', 'lemma', 'upos', '_1', '_2', '_3', '_4', '_5', '_6', '_7', '_8', '_9']

# Read the file, skipping comments and empty lines
with open(file_path, 'r', encoding='utf-8') as f:
    data = [line.strip().split('\t') for line in f if line.strip() and not line.startswith('#')]


# Pad each line with empty strings to ensure it has 13 columns
data = [row + [''] * (len(column_names) - len(row)) if len(row) < len(column_names) else row for row in data]

# Create the DataFrame
df = pd.DataFrame(data, columns=column_names)


# Convert 'id' and '_3' columns to numeric, coercing errors to NaN
df['id'] = pd.to_numeric(df['id'], errors='coerce')
df['_3'] = pd.to_numeric(df['_3'], errors='coerce')

# Print the DataFrame
print(df)


# Get a summary of the DataFrame
print("\nSummary:")
df.info()


# Create a bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size for better visibility
plt.bar(df['id'], df['lemma']) #Bar plot: x-axis is 'id', y-axis is 'lemma'
plt.xlabel("ID")
plt.ylabel("Lemma")
plt.title("Lexical Similarity Scores") #Add a title
plt.xticks(rotation=0)  # Keep x-axis labels horizontal
plt.tight_layout()  # Adjust subplot parameters for a tight layout
plt.show()
# Out:
#        id      form   lemma   upos _1  \
# 0       1  Atenasen  Atenas  PROPN  _
# 1       2     ordea   ordea  CCONJ  _
# 2       3         ,       ,  PUNCT  _
# 3       4     beste   beste    DET  _
# 4       5      bost    bost    NUM  _
# ...    ..       ...     ...    ... ..
# 24090  21      izan    izan    AUX  _
# 24091  22        da    izan    AUX  _
# 24092  23       lur     lur   NOUN  _
# 24093  24      hura    hura    DET  _
# 24094  25         .       .  PUNCT  _
#
#                                                       _2  _3      _4 _5  \
# 0                      Case=Ine|Definite=Def|Number=Sing   8     obl  _
# 1                                                      _   8  advmod  _
# 2                                                      _   2   punct  _
# 3                                                      _   6     det  _
# 4                                           NumType=Card   6  nummod  _
# ...                                                  ...  ..     ... ..
# 24090                          Aspect=Perf|VerbForm=Part  20     cop  _
# 24091  Mood=Ind|Number[abs]=Sing|Person[abs]=3|VerbFo...  20     aux  _
# 24092                                                  _  20   nsubj  _
# 24093                  Case=Abs|Definite=Def|Number=Sing  23     det  _
# 24094                                                  _   9   punct  _
#
#                   _6 _7 _8 _9
# 0                  _
# 1      SpaceAfter=No
# 2                  _
# 3                  _
# 4                  _
# ...              ... .. .. ..
# 24090              _
# 24091              _
# 24092              _
# 24093  SpaceAfter=No
# 24094              _
#
# [24095 rows x 13 columns]
#
# Summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24095 entries, 0 to 24094
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      24095 non-null  int64
#  1   form    24095 non-null  object
#  2   lemma   24095 non-null  object
#  3   upos    24095 non-null  object
#  4   _1      24095 non-null  object
#  5   _2      24095 non-null  object
#  6   _3      24095 non-null  int64
#  7   _4      24095 non-null  object
#  8   _5      24095 non-null  object
#  9   _6      24095 non-null  object
#  10  _7      24095 non-null  object
#  11  _8      24095 non-null  object
#  12  _9      24095 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 2.4+ MB
