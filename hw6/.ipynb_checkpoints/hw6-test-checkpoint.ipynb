# %%
import pandas as pd
import numpy as np

# %%
# Load datasets
languages = pd.read_csv('languages.csv')
parameters = pd.read_csv('parameters.csv')
values = pd.read_csv('values.csv')
codes = pd.read_csv('codes.csv')

# Display dataset shapes
print("Languages shape:", languages.shape)
print("Parameters shape:", parameters.shape)
print("Values shape:", values.shape)
print("Codes shape:", codes.shape)
# Out:
# Languages shape: (2467, 13)
# Parameters shape: (195, 12)
# Values shape: (441663, 9)
# Codes shape: (398, 4)

# %%
# Task 3b: Keep only specific parameters
filtered_values = values[values['Parameter_ID'].isin(['GB020', 'GB022', 'GB023'])]

# Drop unnecessary columns
columns_to_remove = ['ID', 'Comment', 'Source', 'Source_comment', 'Coders']
filtered_values = filtered_values.drop(columns=columns_to_remove, errors='ignore')

# Show data structure
print("Filtered values shape:", filtered_values.shape)
print("Columns after filtering:", filtered_values.columns.tolist())
# Out:
# Filtered values shape: (7149, 4)
# Columns after filtering: ['Language_ID', 'Parameter_ID', 'Value', 'Code_ID']

# %%
# Merge with languages dataset
values_with_lang = filtered_values.merge(languages[['ID', 'Name', 'Macroarea']],
                                         left_on='Language_ID', right_on='ID',
                                         how='left')

# Show data structure
print("After merging languages:", values_with_lang.shape)
print("Columns:", values_with_lang.columns.tolist())
# Out:
# After merging languages: (7149, 7)
# Columns: ['Language_ID', 'Parameter_ID', 'Value', 'Code_ID', 'ID', 'Name', 'Macroarea']

# %%
# Merge descriptions from codes dataset
values_merged = values_with_lang.merge(codes[['ID', 'Description']],
                                       left_on='Code_ID', right_on='ID',
                                       how='left')

# Keep and rename relevant columns
columns_to_keep = ['Language_ID', 'Parameter_ID', 'Value', 'Code_ID', 'Name', 'Macroarea', 'Description']
values_cleaned = values_merged[columns_to_keep].rename(columns={
    'Name': 'Language',
    'Parameter_ID': 'Feature',
    'Description': 'Value'
})

# Show dataset structure
print("Final cleaned dataset shape:", values_cleaned.shape)
print(values_cleaned.tail(5))
# Out:
# Final cleaned dataset shape: (7149, 7)
#      Language_ID Feature Value  Code_ID Language      Macroarea    Value
# 7144    zulu1248   GB022     0  GB022-0     Zulu         Africa   absent
# 7145    zulu1248   GB023     0  GB023-0     Zulu         Africa   absent
# 7146    zuni1245   GB020     1  GB020-1     Zuni  North America  present
# 7147    zuni1245   GB022     0  GB022-0     Zuni  North America   absent
# 7148    zuni1245   GB023     0  GB023-0     Zuni  North America   absent

# %%
# Define feature mapping
feature_mapping = {'GB020': 'defArt', 'GB022': 'prenom', 'GB023': 'postnom'}
values_cleaned['Feature'] = values_cleaned['Feature'].replace(feature_mapping)

# Remove rows with missing values
values_cleaned = values_cleaned.dropna()

# Sort data by Macroarea and Language
values_cleaned = values_cleaned.sort_values(['Macroarea', 'Language']).reset_index(drop=True)

# Show structure after sorting
print("After sorting:")
print(values_cleaned.head(10))
# Out:
# After sorting:
#   Language_ID  Feature Value  Code_ID Language Macroarea    Value
# 0    abee1242   defArt     1  GB020-1      Abé    Africa  present
# 1    abee1242   prenom     0  GB022-0      Abé    Africa   absent
# 2    abee1242  postnom     1  GB023-1      Abé    Africa  present
# 3    ache1245   defArt     0  GB020-0  Acheron    Africa   absent
# 4    ache1245   prenom     0  GB022-0  Acheron    Africa   absent
# 5    ache1245  postnom     0  GB023-0  Acheron    Africa   absent
# 6    acol1236   defArt     0  GB020-0    Acoli    Africa   absent
# 7    acol1236   prenom     0  GB022-0    Acoli    Africa   absent
# 8    acol1236  postnom     0  GB023-0    Acoli    Africa   absent
# 9    afar1241   defArt     0  GB020-0     Afar    Africa   absent

# %%
# Set hierarchical index
values_hierarchical = values_cleaned.set_index(['Macroarea', 'Language'])

# Ensure 'Value' column is a string for querying
values_hierarchical['Value'] = values_hierarchical['Value'].astype(str)

# Show indexed dataset
print("Hierarchical index created:")
print(values_hierarchical.head(10))
print(f"\nIndex levels: {values_hierarchical.index.names}")
# Out:
# Hierarchical index created:
#                    Language_ID  Feature Value  Code_ID    Value
# Macroarea Language
# Africa    Abé         abee1242   defArt     1  GB020-1  present
#           Abé         abee1242   prenom     0  GB022-0   absent
#           Abé         abee1242  postnom     1  GB023-1  present
#           Acheron     ache1245   defArt     0  GB020-0   absent
#           Acheron     ache1245   prenom     0  GB022-0   absent
#           Acheron     ache1245  postnom     0  GB023-0   absent
#           Acoli       acol1236   defArt     0  GB020-0   absent
#           Acoli       acol1236   prenom     0  GB022-0   absent
#           Acoli       acol1236  postnom     0  GB023-0   absent
#           Afar        afar1241   defArt     0  GB020-0   absent
#
# Index levels: ['Macroarea', 'Language']

# %%
# Convert 'Value' column to string before setting index
values_cleaned['Value'] = values_cleaned['Value'].astype(str)

# Set hierarchical index including 'Feature'
values_hierarchical = values_cleaned.set_index(['Macroarea', 'Language', 'Feature'])

# Global distribution of definite articles
global_defart = values_hierarchical.xs('defArt', level='Feature')['Value'].value_counts()
print("Global distribution of definite articles:")
print(global_defart)
print(f"Percentage with definite articles: {global_defart.get('present', 0) / global_defart.sum() * 100:.1f}%")

# Regional distributions (Eurasia & Africa)
for region in ['Eurasia', 'Africa']:
    try:
        region_defart = values_hierarchical.xs(('defArt', region), level=['Feature', 'Macroarea'])['Value'].value_counts()
        print(f"\n{region} distribution:")
        print(region_defart)
    except KeyError:
        print(f"\nNo data found for {region}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 8
#       5 values_hierarchical = values_cleaned.set_index(['Macroarea', 'Language', 'Feature'])
#       7 # Global distribution of definite articles
# ----> 8 global_defart = values_hierarchical.xs('defArt', level='Feature')['Value'].value_counts()
#       9 print("Global distribution of definite articles:")
#      10 print(global_defart)
#
# File ~/venv/lib/python3.13/site-packages/pandas/core/frame.py:7509, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    7506     subset = self.columns.tolist()
#    7508 name = "proportion" if normalize else "count"
# -> 7509 counts = self.groupby(subset, dropna=dropna, observed=False)._grouper.size()
#    7510 counts.name = name
#    7512 if sort:
#
# ...

# %% [raw]
# # Global distribution of definite articles
# global_defart = values_hierarchical.query("Feature == 'defArt'")['Value'].value_counts()
# print("Global distribution of definite articles:")
# print(global_defart)
# print(f"Percentage with definite articles: {global_defart.get('present', 0) / global_defart.sum() * 100:.1f}%")
#
# # Regional distributions (Eurasia & Africa)
# try:
#     eurasia_defart = values_hierarchical.loc['Eurasia'].query("Feature == 'defArt'")['Value'].value_counts()
#     print("\nEurasia distribution:")
#     print(eurasia_defart)
# except KeyError:
#     print("\nNo Eurasia data found")
#
# try:
#     africa_defart = values_hierarchical.loc['Africa'].query("Feature == 'defArt'")['Value'].value_counts()
#     print("\nAfrica distribution:")
#     print(africa_defart)
# except KeyError:
#     print("\nNo Africa data found")

# %%
# Convert values to NumPy array for analysis
value_counts = np.array(global_defart)

# Compute mean and standard deviation of definite article occurrences
mean_defart = np.mean(value_counts)
std_defart = np.std(value_counts)

print(f"\nMean occurrences of definite articles: {mean_defart:.2f}")
print(f"Standard deviation: {std_defart:.2f}")
