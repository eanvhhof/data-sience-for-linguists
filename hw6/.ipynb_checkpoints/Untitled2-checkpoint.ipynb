# %%
import pandas as pd
import numpy as np # NumPy is still useful for some underlying operations and is typically imported with Pandas

# ==============================================================================
# Task 1: Merging the CSV Files into a Single Dataframe
# This task remains largely the same as it primarily involves loading CSVs
# and merging operations, which are core Pandas DataFrame functionalities.
# ==============================================================================

print("--- Starting Task 1 ---")

# Task 1.a) Load the contents of the four files into Pandas DataFrame objects
languages = pd.read_csv('languages.csv')
parameters = pd.read_csv('parameters.csv')
values = pd.read_csv('values.csv')
codes = pd.read_csv('codes.csv')
print("Task 1.a: Loaded CSVs into DataFrames.")

# Task 1.b) Reduce 'values' to parameters GB020, GB022, GB023 and remove columns
# Consistent with previous implementations, using GB020, GB022, GB023.
values = values[values['Parameter_ID'].isin(['GB020', 'GB022', 'GB023'])]
values = values.drop(columns=['ID', 'Comment', 'Source', 'Source_comment', 'Coders'])
print("Task 1.b: Filtered values and removed unnecessary columns.")

# Task 1.c) Merge Name and Macroarea from 'languages' into 'values'
values = pd.merge(values, languages[['ID', 'Name', 'Macroarea']],
                  left_on='Language_ID', right_on='ID', how='left')
values = values.drop(columns=['ID']) # Drop the redundant ID column from languages after merge
print("Task 1.c: Merged language names and macroareas.")

# Task 1.d) Merge value descriptions from 'codes' into 'values'
values = pd.merge(values, codes[['ID', 'Description']],
                  left_on='Code_ID', right_on='ID', how='left')
values = values.drop(columns=['ID']) # Drop the redundant ID column from codes after merge
print("Task 1.d: Merged value descriptions.")

print("\n--- Task 1 End Result (last 3 rows of values DataFrame) ---")
print(values.tail(3))
print("\n")


# ==============================================================================
# Task 2: Getting the values Dataframe into Shape
# This task also remains similar as it involves DataFrame cleaning, renaming,
# and sorting operations.
# ==============================================================================

print("--- Starting Task 2 ---")

# Task 2.a) Remove irrelevant columns and rename remaining ones
values = values.drop(columns=['Value', 'Code_ID'])
values = values.rename(columns={
    'Name': 'Language',
    'Description': 'Value',
    'Parameter_ID': 'Feature'
})
print("Task 2.a: Removed/renamed columns.")

# Task 2.b) Reorder columns and sort the result
values = values[['Language', 'Macroarea', 'Feature', 'Value']]
values = values.sort_values(by=['Macroarea', 'Language'])
print("Task 2.b: Reordered columns and sorted data.")

# Task 2.c) Remove lines with incomplete data and replace feature names
values = values.dropna()
values['Feature'] = values['Feature'].replace({
    'GB020': 'defArt',
    'GB022': 'prenom',
    'GB023': 'postnom'
})
print("Task 2.c: Removed incomplete data and replaced feature names.")

print("\n--- Task 2 End Result (last 3 rows of values DataFrame) ---")
print(values.tail(3))
print("\n")


# ==============================================================================
# Task 3: Hierarchical Indexing (Pandas MultiIndex Implementation)
# This task directly leverages Pandas' MultiIndex capabilities.
# ==============================================================================

print("--- Starting Task 3 ---")

# Task 3.a) Modify values by creating a hierarchical row index
# Creates a MultiIndex with 'Macroarea' as the outer level and 'Language' as the inner.
values_task3a = values.set_index(['Macroarea', 'Language'])
print("Task 3.a: Created hierarchical row index (Macroarea, Language).")

print("\n--- Task 3.a End Result (head of values_task3a) ---")
print(values_task3a.head())
print("\n")


# Task 3.b) Global distribution of presence vs. absence of definite articles
# Uses .xs() (cross-section) to select data at a specific level of the MultiIndex.
print("--- Task 3.b Global Distribution of Definite Articles (Pandas MultiIndex) ---")
# Select rows where 'Feature' level is 'defArt', then count 'Value' occurrences.
global_defart_distribution = values_task3a.xs('defArt', level='Feature')['Value'].value_counts()
print("Global Definite Article Distribution:\n", global_defart_distribution)


print("\n--- Task 3.b Eurasia Distribution of Definite Articles (Pandas MultiIndex) ---")
# Use .loc to select 'Eurasia' from the outer 'Macroarea' level of the index,
# then .xs() to filter for 'defArt' feature, and finally value_counts().
eurasia_defart_distribution = values_task3a.loc['Eurasia'].xs('defArt', level='Feature')['Value'].value_counts()
print("Eurasia Definite Article Distribution:\n", eurasia_defart_distribution)


print("\n--- Task 3.b Africa Distribution of Definite Articles (Pandas MultiIndex) ---")
# Similar to Eurasia, but for 'Africa'.
africa_defart_distribution = values_task3a.loc['Africa'].xs('defArt', level='Feature')['Value'].value_counts()
print("Africa Definite Article Distribution:\n", africa_defart_distribution)
print("\n")


# Task 3.c) Reindex the values dataframe with a different hierarchical row index
# Creates a new MultiIndex with 'Feature' as the outer level and 'Macroarea' as the inner.
reindexed = values.set_index(['Feature', 'Macroarea'])
# Sorts the index by the outermost level ('Feature') to group similar features together.
reindexed = reindexed.sort_index(level='Feature')
print("Task 3.c: Reindexed with (Feature, Macroarea) and sorted by Feature.")

print("\n--- Task 3.c End Result (head of reindexed) ---")
print(reindexed.head())
print("\n")


# Task 3.d) Change the index of reindexed such that macroarea becomes outer, feature inner.
# Then extract all languages with prenominal article position.
# `swaplevel()` exchanges the levels of the MultiIndex.
reindexed_task3d = reindexed.swaplevel(i='Feature', j='Macroarea', axis=0)
# Sort by the new outer level ('Macroarea') for clean display.
reindexed_task3d = reindexed_task3d.sort_index(level='Macroarea')
print("Task 3.d: Swapped index levels to (Macroarea, Feature) and resorted.")

print("\n--- Task 3.d End Result (head after reindex and sort) ---")
print(reindexed_task3d.head())
print("\n")

print("--- Task 3.d Languages with Prenominal Article Position (Pandas MultiIndex) ---")
# Use .loc with a tuple to select rows where Feature is 'prenom' AND Value is 'present'.
# `slice(None)` is used for selecting all elements along a dimension in a MultiIndex.
prenominal_present_languages = reindexed_task3d.loc[(slice(None), 'prenom', 'present'), :]
# Extract unique language names from the 'Language' level of the index.
prenominal_present_languages_list = prenominal_present_languages.index.get_level_values('Language').unique().tolist()
print("Languages with Prenominal Article Position (present):\n", prenominal_present_languages_list)
print("\n")


# ==============================================================================
# Task 4: Pivoting and Melting (Pandas Implementation)
# These tasks are designed for Pandas' `pivot`, `unstack`, `melt`, and `droplevel`.
# ==============================================================================

print("--- Starting Task 4 ---")

# We need the `values_task3a` DataFrame (from Task 3.a), which has (Macroarea, Language) as index.

# Task 4.a) Decide whether to use pivoting or melting... Store as languages_rows.
# We use `unstack` to pivot the 'Feature' level from the row index to new columns.
# This results in a DataFrame with Macroarea and Language as a MultiIndex for rows,
# and defArt, prenom, postnom as columns containing their 'Value'.
languages_rows = values_task3a.unstack(level='Feature')
print("Task 4.a: Pivoted 'Feature' to columns using unstack().")

print("\n--- Task 4.a languages_rows (head) ---")
print(languages_rows.head())
print("\n")


# Task 4.b) Remove unnecessary outer level in the column index.
# The `unstack` operation creates a MultiIndex in columns if the unstacked level
# was part of a MultiIndex. Here, 'Value' is the outer column level.
# `droplevel(level=0, axis=1)` removes the outermost level (which is 'Value' from original column name).
languages_rows = languages_rows.droplevel(level=0, axis=1)
print("Task 4.b: Removed outer level from column index using droplevel().")

print("\n--- Task 4.b languages_rows (head after droplevel) ---")
print(languages_rows.head())
print("\n")


# Task 4.c) Which languages feature definite articles in both postnominal and prenominal position.
# This involves simple boolean indexing on the `languages_rows` DataFrame.
languages_with_both_prenom_postnom = languages_rows[
    (languages_rows['prenom'] == 'present') &
    (languages_rows['postnom'] == 'present')
]
# The language names are in the inner level of the row MultiIndex.
languages_with_both_prenom_postnom_list = languages_with_both_prenom_postnom.index.get_level_values('Language').tolist()
print("Task 4.c: Identified languages with both prenominal and postnominal definite articles.")

print("--- Task 4.c Languages with Definite Articles in Both Postnominal and Prenominal Position ---")
print(languages_with_both_prenom_postnom_list)
print("\n")


# Task 4.d) Which three method calls can we chain together to transform this version of languages_rows
# back into a format that is as similar as possible to the original version of values at the end of Task 2?
print("--- Task 4.d Chained method calls to revert ---")
print("To revert `languages_rows` back to the 'long' format of `values` (Task 2 end), "
      "you would chain these three Pandas methods:")
print("1. `.reset_index()`: Converts the MultiIndex (Macroarea, Language) back into regular columns.")
print("2. `.melt(id_vars=['Macroarea', 'Language'], var_name='Feature', value_name='Value')`: "
      "Transforms the feature columns (defArt, prenom, postnom) back into rows, creating 'Feature' "
      "and 'Value' columns. `id_vars` specifies columns to keep as identifiers.")
print("3. `.sort_values(by=['Macroarea', 'Language'])`: Sorts the resulting DataFrame to match "
      "the original sorting order of the `values` DataFrame from Task 2.")
print("Example of chained calls (not executing, just for demonstration):")
print("re_melted_values = languages_rows.reset_index().melt(")
print("    id_vars=['Macroarea', 'Language'],")
print("    var_name='Feature',")
print("    value_name='Value'")
print(").sort_values(by=['Macroarea', 'Language'])")
print("\n")


# ==============================================================================
# Task 5: Concatenation (Pandas Implementation)
# This task uses `pd.concat` with its various options for axis, keys, and join types.
# ==============================================================================

print("--- Starting Task 5 ---")

# Task 5.a) Extract from 'values' three dataframes, each containing only one feature.
# We will use the `values` DataFrame from the end of Task 2, which is in long format.
def_art_data = values[values['Feature'] == 'defArt']
prenom_data = values[values['Feature'] == 'prenom']
postnom_data = values[values['Feature'] == 'postnom']
print("Task 5.a: Extracted feature-specific DataFrames.")

print("\n--- Task 5.a Dataframe head examples ---")
print("def_art_data head:\n", def_art_data.head())
print("\nprenom_data head:\n", prenom_data.head())
print("\npostnom_data head:\n", postnom_data.head())
print("\n")


# Task 5.b) Concatenate the three dataframes along the column axis, with feature names as keys,
# and limit to complete rows (inner join).
# First, set a common index (Macroarea, Language) for alignment, and select only the 'Value' column
# while renaming it to the feature name for the new column.
def_art_data_pivot = def_art_data.set_index(['Macroarea', 'Language'])[['Value']].rename(columns={'Value': 'defArt'})
prenom_data_pivot = prenom_data.set_index(['Macroarea', 'Language'])[['Value']].rename(columns={'Value': 'prenom'})
postnom_data_pivot = postnom_data.set_index(['Macroarea', 'Language'])[['Value']].rename(columns={'Value': 'postnom'})

# Concatenate along axis=1 (columns). `join='inner'` ensures only rows common to all are included.
# `keys` argument creates a MultiIndex in the columns, but as we renamed columns, it's effectively flattened.
# If we wanted a MultiIndex (Value, Feature), we'd pass original DataFrames and then unstack.
# Here, the request implies the feature names *are* the column names.
concatenated_columns_complete = pd.concat(
    [def_art_data_pivot, prenom_data_pivot, postnom_data_pivot],
    axis=1,
    join='inner' # Limits output to complete rows (intersection of indices)
)
print("Task 5.b: Concatenated along column axis with inner join.")

print("\n--- Task 5.b Concatenated along column axis (head) ---")
print(concatenated_columns_complete.head())
print("\n")


# Task 5.c) Concatenate along the row axis, with an additional outermost layer of hierarchical row index (feature names).
# Extract the single column into a Series object with a three-level hierarchical index.
# For this, we need to ensure each dataframe has a consistent structure that results in
# the desired (Feature_Key, Macroarea, Language) MultiIndex.
# We'll set (Macroarea, Language) as index for each, and then concat with keys.

# Ensure the 'Feature' column is still present in the dataframes for the keys to work naturally.
# The original def_art_data, prenom_data, postnom_data already have 'Language', 'Macroarea', 'Feature', 'Value'.
# We need to set Macroarea and Language as part of the index for each, then concatenate the 'Value' series.
# The 'keys' argument will add the outermost level.

series_with_hierarchical_index = pd.concat(
    [
        def_art_data.set_index(['Macroarea', 'Language'])['Value'],
        prenom_data.set_index(['Macroarea', 'Language'])['Value'],
        postnom_data.set_index(['Macroarea', 'Language'])['Value']
    ],
    axis=0,
    keys=['defArt', 'prenom', 'postnom'] # This creates the outermost hierarchical index level
)

# Sort the index to ensure the hierarchical levels are correctly ordered.
series_with_hierarchical_index = series_with_hierarchical_index.sort_index()
print("Task 5.c: Concatenated along row axis with hierarchical index and extracted as Series.")

print("\n--- Task 5.c Series with Three-Level Hierarchical Index (head) ---")
print(series_with_hierarchical_index.head())
print("\n")
# Out:
# --- Starting Task 1 ---
# Task 1.a: Loaded CSVs into DataFrames.
# Task 1.b: Filtered values and removed unnecessary columns.
# Task 1.c: Merged language names and macroareas.
# Task 1.d: Merged value descriptions.
#
# --- Task 1 End Result (last 3 rows of values DataFrame) ---
#      Language_ID Parameter_ID Value  Code_ID  Name      Macroarea Description
# 7146    zuni1245        GB020     1  GB020-1  Zuni  North America     present
# 7147    zuni1245        GB022     0  GB022-0  Zuni  North America      absent
# 7148    zuni1245        GB023     0  GB023-0  Zuni  North America      absent
#
#
# --- Starting Task 2 ---
# Task 2.a: Removed/renamed columns.
# Task 2.b: Reordered columns and sorted data.
# Task 2.c: Removed incomplete data and replaced feature names.
#
# --- Task 2 End Result (last 3 rows of values DataFrame) ---
#      Language      Macroarea  Feature    Value
# 6914   Yámana  South America   defArt   absent
# 6915   Yámana  South America   prenom   absent
# ...
